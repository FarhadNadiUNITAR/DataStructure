# %%
# Linked List Node class
class Node:
    def __init__(self, data):
        self.data = data    # data/value/information
        self.next = None    # reference/link to the next node
    def show_nodes(self):
        return self.data, self.next

# %%
node1 = Node(1)
node1_value, node1_link = node1.show_nodes()
print('node value: ', node1_value, ' , node reference: ', node1_link)
# Out:
# node value:  1  , node reference:  None

# %%
node2 = Node(2)
node2_value, node2_link = node2.show_nodes()
print('node value: ', node2_value, ' , node reference: ', node2_link)
# Out:
# node value:  2  , node reference:  None

# %%
node3 = Node(3)
node3_value, node3_link = node3.show_nodes()
print('node value: ', node3_value, ' , node reference: ', node3_link)
# Out:
# node value:  3  , node reference:  None

# %%
### All the above nodes are not connected with each other. All the reference (next) is null. Not linked with each other.
###
### Let's connect them and create a chain.

# %%
# Linked List Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        print('Address of the node ',self.data, ' -> ', self)

### Insertion at begining of the linked list
# Linked List class


class LinkedList:
    def __init__(self):
        self.head = None  # Initialize an empty linked list

    def insertAtBeginning(self, value):
        """
        Inserts a new node with the given value at the beginning of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node


    def traverseList(self):
        """
        Traverses and prints the elements of the linked list.
        """
        currentNode = self.head  # Start from the head node
        while currentNode is not None:  # Traverse the list
            print(currentNode.data, end=" ")  # Print the data of the current node
            print(', Node ', currentNode.data, 'has reference/link ',currentNode.next)
            currentNode = currentNode.next

        print()



# Example usage
linkedlist = LinkedList()

# Inserting nodes at the beginning
linkedlist.insertAtBeginning(3)
linkedlist.insertAtBeginning(2)
linkedlist.insertAtBeginning(1)

print()
# Traversing the linked list
linkedlist.traverseList()
# Out:
# Address of the node  3  ->  <__main__.Node object at 0x7fe317602aa0>
# Address of the node  2  ->  <__main__.Node object at 0x7fe317601d50>
# Address of the node  1  ->  <__main__.Node object at 0x7fe317603400>
#
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe317601d50>
# 2 , Node  2 has reference/link  <__main__.Node object at 0x7fe317602aa0>
# 3 , Node  3 has reference/link  None

# %%
# Linked List Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        print('Address of the node ',self.data, ' -> ', self)

### Let's extend above LinkedList class
### Insertion at begining of the linked list (insertAtBeginning)
### Now we have intoduced another method, insertion at the end of the linked list (insertAtEnd)

# Linked List class
class LinkedList:
    def __init__(self):
        self.head = None  # Initialize an empty linked list

    def insertAtBeginning(self, value):
        """
        Inserts a new node with the given value at the beginning of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node

    def insertAtEnd(self, value):
        """
        Inserts a new node with the given value at the end of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            currentNode = self.head  # Start from the head node
            while currentNode.next is not None:  # Traverse the list to find the last node
                currentNode = currentNode.next
            currentNode.next = newNode  # Set the next pointer of the last node to the new node

    def traverseList(self):
        """
        Traverses and prints the elements of the linked list.
        """
        currentNode = self.head  # Start from the head node
        while currentNode is not None:  # Traverse the list
            print(currentNode.data, end=" ")  # Print the data of the current node
            print(', Node ', currentNode.data, 'has reference/link ',currentNode.next)
            currentNode = currentNode.next
        print()


# Example usage
linkedlist = LinkedList()

# Inserting nodes at the beginning
linkedlist.insertAtBeginning(3)
linkedlist.insertAtBeginning(2)
linkedlist.insertAtBeginning(1)

# Inserting nodes at the end
linkedlist.insertAtEnd(5)
linkedlist.insertAtEnd(6)

print()
# Traversing the linked list
linkedlist.traverseList()
# Out:
# Address of the node  3  ->  <__main__.Node object at 0x7fe3178be6e0>
# Address of the node  2  ->  <__main__.Node object at 0x7fe3178bd570>
# Address of the node  1  ->  <__main__.Node object at 0x7fe3178bc580>
# Address of the node  5  ->  <__main__.Node object at 0x7fe3178bd750>
# Address of the node  6  ->  <__main__.Node object at 0x7fe3178bec80>
#
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe3178bd570>
# 2 , Node  2 has reference/link  <__main__.Node object at 0x7fe3178be6e0>
# 3 , Node  3 has reference/link  <__main__.Node object at 0x7fe3178bd750>
# 5 , Node  5 has reference/link  <__main__.Node object at 0x7fe3178bec80>
# 6 , Node  6 has reference/link  None

# %%
# Linked List Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        print('Address of the node ',self.data, ' -> ', self)

### Let's extend above LinkedList class
### Insertion at begining of the linked list (insertAtBeginning)
### Insertion at the end of the linked list (insertAtEnd)
### Insertion at a specific position of the linked list (insertAtPosition)

# Linked List class
class LinkedList:
    def __init__(self):
        self.head = None  # Initialize an empty linked list

    def insertAtBeginning(self, value):
        """
        Inserts a new node with the given value at the beginning of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node

    def insertAtEnd(self, value):
        """
        Inserts a new node with the given value at the end of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            currentNode = self.head  # Start from the head node
            while currentNode.next is not None:  # Traverse the list to find the last node
                currentNode = currentNode.next
            currentNode.next = newNode  # Set the next pointer of the last node to the new node


    def insertAtPosition(self, value, position):
        """
        Inserts a new node with the given value at the specified position in the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if position == 1:  # Check if the position is the first position
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node
        else:
            currentNode = self.head  # Start from the head node
            currentPosition = 1

            while currentPosition < position - 1:  # Traverse the list to find the position just before the desired insertion position
                currentNode = currentNode.next
                currentPosition += 1

            newNode.next = currentNode.next  # Set the next pointer of the new node to the next node of the current node
            currentNode.next = newNode  # Set the next pointer of the current node to the new node

    def traverseList(self):
        """
        Traverses and prints the elements of the linked list.
        """
        currentNode = self.head  # Start from the head node
        while currentNode is not None:  # Traverse the list
            print(currentNode.data, end=" ")  # Print the data of the current node
            print(', Node ', currentNode.data, 'has reference/link ',currentNode.next)
            currentNode = currentNode.next
        print()

# Example usage
linkedlist = LinkedList()

# Inserting nodes at the beginning
linkedlist.insertAtBeginning(3)
linkedlist.insertAtBeginning(2)
linkedlist.insertAtBeginning(1)

# Inserting nodes at the end
linkedlist.insertAtEnd(5)
linkedlist.insertAtEnd(6)

print()
# Traversing the linked list
linkedlist.traverseList()

# Inserting a node at a specific position
linkedlist.insertAtPosition(3, 2)

print()
# Traversing the modified linked list
linkedlist.traverseList()
# Out:
# Address of the node  3  ->  <__main__.Node object at 0x7fe33be8eaa0>
# Address of the node  2  ->  <__main__.Node object at 0x7fe33be8f430>
# Address of the node  1  ->  <__main__.Node object at 0x7fe33be8ddb0>
# Address of the node  5  ->  <__main__.Node object at 0x7fe3176034c0>
# Address of the node  6  ->  <__main__.Node object at 0x7fe317600a90>
#
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe33be8f430>
# 2 , Node  2 has reference/link  <__main__.Node object at 0x7fe33be8eaa0>
# 3 , Node  3 has reference/link  <__main__.Node object at 0x7fe3176034c0>
# 5 , Node  5 has reference/link  <__main__.Node object at 0x7fe317600a90>
# 6 , Node  6 has reference/link  None
#
# Address of the node  3  ->  <__main__.Node object at 0x7fe33be8f070>
#
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe33be8f070>
# 3 , Node  3 has reference/link  <__main__.Node object at 0x7fe33be8f430>
# 2 , Node  2 has reference/link  <__main__.Node object at 0x7fe33be8eaa0>
# ...

# %%
# Linked List Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        print('Address of the node ',self.data, ' -> ', self)



### Let's extend above LinkedList class
### Insertion at begining of the linked list (insertAtBeginning)
### Insertion at the end of the linked list (insertAtEnd)
### Insertion at a specific position of the linked list (insertAtPosition)
### Deleting a node in the linked list (deleteNode)


# Linked List class
class LinkedList:
    def __init__(self):
        self.head = None  # Initialize an empty linked list

    def insertAtBeginning(self, value):
        """
        Inserts a new node with the given value at the beginning of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node

    def insertAtEnd(self, value):
        """
        Inserts a new node with the given value at the end of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            currentNode = self.head  # Start from the head node
            while currentNode.next is not None:  # Traverse the list to find the last node
                currentNode = currentNode.next
            currentNode.next = newNode  # Set the next pointer of the last node to the new node

    def deleteNode(self, value):
        """
        Deletes the first occurrence of a node with the given value from the linked list.
        """
        if self.head is None:  # Check if the list is empty
            return self.head

        if self.head.data == value:  # Check if the head node has the value to be deleted
            self.head = self.head.next  # Update the head to the next node
            return self.head

        currentNode = self.head  # Start from the head node
        while currentNode.next is not None:  # Traverse the list to find the node to be deleted
            if currentNode.next.data == value:  # Check if the next node has the value to be deleted
                currentNode.next = currentNode.next.next  # Skip the next node by updating the next pointer
                break
            currentNode = currentNode.next

        return self.head


    def insertAtPosition(self, value, position):
        """
        Inserts a new node with the given value at the specified position in the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if position == 1:  # Check if the position is the first position
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node
        else:
            currentNode = self.head  # Start from the head node
            currentPosition = 1

            while currentPosition < position - 1:  # Traverse the list to find the position just before the desired insertion position
                currentNode = currentNode.next
                currentPosition += 1

            newNode.next = currentNode.next  # Set the next pointer of the new node to the next node of the current node
            currentNode.next = newNode  # Set the next pointer of the current node to the new node


    def traverseList(self):
        """
        Traverses and prints the elements of the linked list.
        """
        currentNode = self.head  # Start from the head node
        while currentNode is not None:  # Traverse the list
            print(currentNode.data, end=" ")  # Print the data of the current node
            print(', Node ', currentNode.data, 'has reference/link ',currentNode.next)
            currentNode = currentNode.next
        print()

# Example usage
linkedlist = LinkedList()

# Inserting nodes at the beginning
linkedlist.insertAtBeginning(4)
linkedlist.insertAtBeginning(2)
linkedlist.insertAtBeginning(1)

# Inserting nodes at the end
linkedlist.insertAtEnd(5)
linkedlist.insertAtEnd(6)

# Deleting a node
linkedlist.deleteNode(2)

print()
# Traversing the linked list
linkedlist.traverseList()

# Inserting a node at a specific position
linkedlist.insertAtPosition(3, 2)

# Deleting a node
# linkedlist.deleteNode(2)

# Traversing the modified linked list
linkedlist.traverseList()

# Deleting a node
linkedlist.deleteNode(5)

print()
# Traversing the modified linked list
linkedlist.traverseList()
# Out:
# Address of the node  4  ->  <__main__.Node object at 0x7fe317634460>
# Address of the node  2  ->  <__main__.Node object at 0x7fe3176357b0>
# Address of the node  1  ->  <__main__.Node object at 0x7fe317637430>
# Address of the node  5  ->  <__main__.Node object at 0x7fe317636b00>
# Address of the node  6  ->  <__main__.Node object at 0x7fe3176350f0>
#
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe317634460>
# 4 , Node  4 has reference/link  <__main__.Node object at 0x7fe317636b00>
# 5 , Node  5 has reference/link  <__main__.Node object at 0x7fe3176350f0>
# 6 , Node  6 has reference/link  None
#
# Address of the node  3  ->  <__main__.Node object at 0x7fe317634580>
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe317634580>
# 3 , Node  3 has reference/link  <__main__.Node object at 0x7fe317634460>
# 4 , Node  4 has reference/link  <__main__.Node object at 0x7fe317636b00>
# 5 , Node  5 has reference/link  <__main__.Node object at 0x7fe3176350f0>
# ...

# %%
# Linked List Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        print('Address of the node ',self.data, ' -> ', self)


### Let's extend above LinkedList class
### Insertion at begining of the linked list (insertAtBeginning)
### Insertion at the end of the linked list (insertAtEnd)
### Insertion at a specific position of the linked list (insertAtPosition)
### Deleting a node in the linked list (deleteNode)
### Searching for a specific node in the linked list (searchNode)


# Linked List class
class LinkedList:
    def __init__(self):
        self.head = None  # Initialize an empty linked list

    def insertAtBeginning(self, value):
        """
        Inserts a new node with the given value at the beginning of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node

    def insertAtEnd(self, value):
        """
        Inserts a new node with the given value at the end of the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if self.head is None:  # Check if the list is empty
            self.head = newNode  # Make the new node the head of the list
        else:
            currentNode = self.head  # Start from the head node
            while currentNode.next is not None:  # Traverse the list to find the last node
                currentNode = currentNode.next
            currentNode.next = newNode  # Set the next pointer of the last node to the new node

    def deleteNode(self, value):
        """
        Deletes the first occurrence of a node with the given value from the linked list.
        """
        if self.head is None:  # Check if the list is empty
            return self.head

        if self.head.data == value:  # Check if the head node has the value to be deleted
            self.head = self.head.next  # Update the head to the next node
            return self.head

        currentNode = self.head  # Start from the head node
        while currentNode.next is not None:  # Traverse the list to find the node to be deleted
            if currentNode.next.data == value:  # Check if the next node has the value to be deleted
                currentNode.next = currentNode.next.next  # Skip the next node by updating the next pointer
                break
            currentNode = currentNode.next

        return self.head

    def searchNode(self, value):
        """
        Searches for a node with the given value in the linked list.
        Returns True if the value is found, False otherwise.
        """
        currentNode = self.head  # Start from the head node
        while currentNode is not None:  # Traverse the list
            if currentNode.data == value:  # Check if the current node has the value
                return True
            currentNode = currentNode.next

        return False  # Value not found

    def traverseList(self):
        """
        Traverses and prints the elements of the linked list.
        """
        currentNode = self.head  # Start from the head node
        while currentNode is not None:  # Traverse the list
            print(currentNode.data, end=" ")  # Print the data of the current node
            print(', Node ', currentNode.data, 'has reference/link ',currentNode.next)
            currentNode = currentNode.next
        print()

    def insertAtPosition(self, value, position):
        """
        Inserts a new node with the given value at the specified position in the linked list.
        """
        newNode = Node(value)  # Create a new node with the given value

        if position == 1:  # Check if the position is the first position
            newNode.next = self.head  # Set the next pointer of the new node to the current head
            self.head = newNode  # Update the head to the new node
        else:
            currentNode = self.head  # Start from the head node
            currentPosition = 1

            while currentPosition < position - 1:  # Traverse the list to find the position just before the desired insertion position
                currentNode = currentNode.next
                currentPosition += 1

            newNode.next = currentNode.next  # Set the next pointer of the new node to the next node of the current node
            currentNode.next = newNode  # Set the next pointer of the current node to the new node

# Example usage
linkedlist = LinkedList()

# Inserting nodes at the beginning
linkedlist.insertAtBeginning(4)
linkedlist.insertAtBeginning(2)
linkedlist.insertAtBeginning(1)

# Inserting nodes at the end
linkedlist.insertAtEnd(5)
linkedlist.insertAtEnd(6)

# Deleting a node
linkedlist.deleteNode(2)

# Searching for a node
print(linkedlist.searchNode(5))
print(linkedlist.searchNode(2))

print()
# Traversing the linked list
linkedlist.traverseList()

# Inserting a node at a specific position
linkedlist.insertAtPosition(3, 2)

print()
# Traversing the modified linked list
linkedlist.traverseList()

# Inserting a node at a specific position
linkedlist.insertAtPosition(2, 2)

print()
# Traversing the modified linked list
linkedlist.traverseList()

# Searching for a node
print(linkedlist.searchNode(2))
# Out:
# Address of the node  4  ->  <__main__.Node object at 0x7fe33be8e620>
# Address of the node  2  ->  <__main__.Node object at 0x7fe33be8fd90>
# Address of the node  1  ->  <__main__.Node object at 0x7fe33be8d900>
# Address of the node  5  ->  <__main__.Node object at 0x7fe33be8ef20>
# Address of the node  6  ->  <__main__.Node object at 0x7fe33be8f700>
# True
# False
#
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe33be8e620>
# 4 , Node  4 has reference/link  <__main__.Node object at 0x7fe33be8ef20>
# 5 , Node  5 has reference/link  <__main__.Node object at 0x7fe33be8f700>
# 6 , Node  6 has reference/link  None
#
# Address of the node  3  ->  <__main__.Node object at 0x7fe3178be380>
#
# 1 , Node  1 has reference/link  <__main__.Node object at 0x7fe3178be380>
# 3 , Node  3 has reference/link  <__main__.Node object at 0x7fe33be8e620>
# 4 , Node  4 has reference/link  <__main__.Node object at 0x7fe33be8ef20>
# ...
